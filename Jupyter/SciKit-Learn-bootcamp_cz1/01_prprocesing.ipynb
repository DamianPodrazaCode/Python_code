# %% [markdown]
# ### Strona biblioteki: https://scikit-learn.org
# ### Dokumentacja/User Guide: https://scikit-learn.org/stable/user_guide.html

# %%
import numpy as np
import pandas as pd
import sklearn

sklearn.__version__
# Out:
# '1.7.1'

# %%
data = {
 'size' : ['XL', 'L', 'M', 'L', 'M'],
    'color' : ['red', 'green', 'blue', 'gree', 'red']
}
