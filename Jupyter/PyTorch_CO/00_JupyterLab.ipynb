# %% [markdown]
# # 0. Przygotowanie Środowiska

# %%
# Instalacja Python 3.10+ Anaconda
# Utworzenie wirtualnego środowiska: pytorch_env

# %%
# Instalacja pakietów:
# conda install jupyterlab numpy pandas scipy matplotlib seaborn scikit-learn
# ??? stare conda install pytorch torchvision torchaudio -c pytorch
# pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu130 (to jest nowe ale najlepiej sprawdzić na stronie https://pytorch.org/get-started/locally/)
# pip install plotly nbformat
